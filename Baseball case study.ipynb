# %% [markdown]
# # Baseball case Study

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
df.shape
# Out:
# (30, 17)

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
df.nunique()
# Out:
# W      24
# R      28
# AB     29
# H      29
# 2B     22
# 3B     23
# HR     27
# BB     29
# SO     29
# SB     27
# RA     30
# ER     30
# ERA    30
# CG      9
# SHO    12
# SV     20
# E      21
# dtype: int64

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
plt.figure(figsize=(20,25))
ptnum=1
for columns in df:
    if ptnum<=18:
        ax=plt.subplot(6,4,ptnum)
        sns.boxplot(df[columns],color='b')
        plt.xlabel(columns)
    ptnum+=1
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.title('Wins and runs')
sns.regplot(x='W',y='R',data=df)
plt.xlabel('Wins')
plt.ylabel('Runs')
# Out:
# Text(0, 0.5, 'Runs')

# %%
plt.figure(figsize=(20,25))
p=1
for i in df:
    if p<=17:
        plt.subplot(5,4,p)
        sns.regplot(x='W',y=i,data=df,color='b')
        plt.xlabel('Wins')
        plt.ylabel(i)
        
    p+=1
    
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.title("Wins and CG")
sns.scatterplot(x='W',y='CG',data=df)
plt.xlabel('Wins')
plt.ylabel('CG')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.title("Wins and Hits")
sns.scatterplot(x='W',y='H',data=df)
plt.xlabel('Wins')
plt.ylabel('H')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.title("CG and Hits")
sns.lineplot(x='CG',y='H',data=df)
plt.xlabel('Caompete Games')
plt.ylabel('Hits')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.title("ER and ERA")
sns.scatterplot(x='ER',y='ERA',data=df)
plt.xlabel('ER')
plt.ylabel('ERA')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.title("RA and ERA")
sns.lineplot(x='RA',y='ERA',data=df)
plt.xlabel('RA')
plt.ylabel('ERA')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.title("RA and ER")
sns.lineplot(x='RA',y='ER',data=df)
plt.xlabel('RA')
plt.ylabel('ER')
plt.show()

# %%
df=df.drop('ERA',axis=1)

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER  CG  SHO  SV  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601   2    8  56
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653   2   12  45
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  11   10  38
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643   7    9  37
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746   7   12  35
#
#      E
# 0   88
# 1   86
# 2   79
# 3  101
# 4   86

# %%
plt.figure(figsize=(8,5))
plt.title("RA and ER")
sns.scatterplot(x='RA',y='ER',data=df)
plt.xlabel('RA')
plt.ylabel('ER')
plt.show()

# %%
from sklearn.feature_selection import SelectPercentile
from sklearn.feature_selection import chi2
x=df.drop('W',axis=1)
y=df.W

# %%
percentile=SelectPercentile(score_func=chi2,percentile=90)
percentile=percentile.fit(x,y)
bestf=percentile.get_support(indices=True)

# %%
feature=x.columns[bestf]
df_new=x[feature]
df_new['W']=df['W']
df_new
# Out:
#       R     H  3B   HR   BB    SO   SB   RA   ER  CG  SHO  SV    E    W
# 0   724  1497  42  139  383   973  104  641  601   2    8  56   88   95
# 1   696  1349  44  156  439  1264   70  700  653   2   12  45   86   83
# 2   669  1395  29  141  533  1157   86  640  584  11   10  38   79   81
# 3   622  1381  27  136  404  1231   68  701  643   7    9  37  101   76
# 4   689  1515  49  151  455  1259   83  803  746   7   12  35   86   74
# 5   891  1480  17  232  570  1151   88  670  609   7   10  34   88   93
# 6   764  1397  19  212  554  1227   63  698  652   3    4  48   93   87
# 7   713  1370  20  217  418  1331   44  693  646   0   10  43   77   81
# 8   644  1383  32  167  436  1310   87  642  604   1   12  60   95   80
# 9   748  1495  33  161  478  1148   71  753  694   3   10  40   97   78
# 10  751  1419  32  172  503  1233  101  733  680   5    9  45  119   88
# 11  729  1363  26  230  486  1392  121  618  572   5   13  39   85   86
# ...

# %%
feature
# Out:
# Index(['R', 'H', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER', 'CG', 'SHO', 'SV',
#        'E'],
#       dtype='object')

# %%
df_new.corr()
# Out:
#             R         H        3B        HR        BB        SO        SB  \
# R    1.000000  0.482856 -0.070072  0.671283  0.402452 -0.054726  0.081367
# H    0.482856  1.000000  0.478694 -0.090855 -0.118281 -0.398830  0.413444
# 3B  -0.070072  0.478694  1.000000 -0.430915 -0.454949 -0.141196  0.457437
# HR   0.671283 -0.090855 -0.430915  1.000000  0.425691  0.359923 -0.136567
# BB   0.402452 -0.118281 -0.454949  0.425691  1.000000  0.233652 -0.098347
# SO  -0.054726 -0.398830 -0.141196  0.359923  0.233652  1.000000  0.030968
# SB   0.081367  0.413444  0.457437 -0.136567 -0.098347  0.030968  1.000000
# RA  -0.041623  0.224324  0.314125 -0.103903 -0.416445 -0.129745  0.132290
# ER  -0.041245  0.252489  0.340225 -0.085922 -0.452663 -0.161612  0.143068
# CG   0.232042  0.147955 -0.065898  0.156502  0.462478 -0.093418 -0.020783
# SHO -0.103274 -0.145559 -0.041396 -0.019119  0.426004  0.237721 -0.106563
# SV  -0.096380 -0.130371 -0.142370 -0.028540  0.099445  0.126297 -0.183418
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df_new.corr(),annot=True,cmap='CMRmap_r')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.title("SV and RA")
sns.scatterplot(x='SV',y='RA',data=df,hue='W')
plt.xlabel('SV')
plt.ylabel('RA')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.title("SV and ER")
sns.scatterplot(x='SV',y='ER',data=df)
plt.xlabel('SV')
plt.ylabel('ER')
plt.show()

# %%
plt.figure(figsize=(22,7))
plt.title("Label and Features")
df_new.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar',color='b')
plt.xlabel('Features')
plt.ylabel('Target')
plt.show()

# %%
plt.figure(figsize=(20,25))
p=1
for i in df_new:
    if p<=13:
        plt.subplot(5,4,p)
        sns.boxplot(df_new[i])
        plt.xlabel(i)
    p+=1
plt.show()

# %%
from scipy.stats import zscore
out_features=df_new[['R','SV','E']]
z=np.abs(zscore(out_features))
z
# Out:
#            R        SV         E
# 0   0.619078  1.671607  0.461470
# 1   0.134432  0.249879  0.607197
# 2   0.332906  0.654856  1.117242
# 3   1.146419  0.784104  0.485758
# 4   0.013270  1.042600  0.607197
# 5   3.509647  1.171848  0.461470
# 6   1.311430  0.637623  0.097152
# 7   0.428681  0.008617  1.262970
# 8   0.765626  2.188598  0.048576
# 9   1.034489  0.396360  0.194303
# 10  1.086415  0.249879  1.797303
# 11  0.705622  0.525608  0.680061
# 12  0.471376  0.379127  0.097152
# 13  0.557920  0.249879  0.024288
# 14  0.099814  1.947335  2.307348
# 15  0.713699  2.447094  0.121439
# 16  0.151740  1.413111  2.015894
# 17  0.013270  0.637623  1.214394
# 18  0.575229  0.396360  1.578712
# 19  0.834861  1.042600  0.315742
# 20  0.090583  0.896119  0.461470
# 21  0.255593  0.267112  0.315742
# 22  1.302198  1.042600  1.262970
# 23  1.994550  0.120631  0.315742
# 24  1.077184  1.042600  1.651576
# 25  0.367523  0.508375  1.408697
# 26  0.134432  0.267112  1.190106
# ...

# %%
new_df=df_new[(z<3).all(axis=1)]
new_df.shape
# Out:
# (29, 14)

# %%
df_new.shape
# Out:
# (30, 14)

# %%
(30-29)/30*100
# Out:
# 3.3333333333333335

# %%
Q1=out_features.quantile(0.25)

Q3=out_features.quantile(0.75)

IQR=Q3-Q1

new_df1=df_new[~((df_new < (Q1-1.5*IQR)) | (df_new >(Q3 + 1.5*IQR))).any(axis=1)]

# %%
new_df1.shape
# Out:
# (23, 14)

# %%
(30-23)/30*100
# Out:
# 23.333333333333332

# %%
df_new=new_df

# %%
df_new.skew()
# Out:
# R     -0.215364
# H      0.783772
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# W      0.119013
# dtype: float64

# %%
skewed_col=['H','CG','SV','E']
from sklearn.preprocessing import PowerTransformer
scaler=PowerTransformer(method='yeo-johnson')

# %%
df_new[skewed_col]=scaler.fit_transform(df_new[skewed_col].values)
df_new[skewed_col].head()
# Out:
#               H        CG        SV         E
# 0  4.163336e-16 -0.307098  1.532753 -0.348265
# 1 -2.498002e-16 -0.307098  0.312020 -0.540820
# 2  0.000000e+00  2.011315 -0.664137 -1.326125
# 3 -8.326673e-17  1.264463 -0.820689  0.650818
# 4  4.718448e-16  1.264463 -1.149165 -0.540820

# %%
df_new.skew()
# Out:
# R     -0.215364
# H      0.000000
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# CG    -0.045947
# SHO    0.526943
# SV    -0.000925
# E      0.065585
# W      0.119013
# dtype: float64

# %%
plt.figure(figsize=(20,25))
pltnum=1
for column in df_new:
    if pltnum <= 13:
        ax=plt.subplot(4,4,pltnum)
        sns.distplot(df_new[column])
        plt.xlabel(column)
    pltnum+=1
plt.show()

# %%
x =df_new.drop('W',axis=1)
y=df_new['W']
print('Feature Dimentions',x.shape)
print('Label Dimention',y.shape)
# Out:
# Feature Dimentions (29, 13)
# Label Dimention (29,)

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#            R         H        3B        HR        BB        SO        SB  \
# 0   0.962544  1.677211  1.006150 -0.741927 -1.605198 -2.550612  0.936132
# 1   0.298863 -0.859086  1.185227 -0.109958 -0.462096  0.093683 -0.516377
# 2  -0.312105 -0.056461 -0.228819 -0.664354  1.232098 -0.935611  0.225038
# 3  -1.308298 -0.056461 -0.432228 -0.860039 -1.162721 -0.230683 -0.618422
# 4   0.137737  1.677211  1.622636 -0.289647 -0.155686  0.044143  0.095038
# 5   1.964209 -0.056461 -1.295827  1.631637  1.579494 -0.269583 -0.884526
# 6   0.698146 -0.859086 -1.182758  1.767734 -0.877217  0.770980 -2.082843
# 7  -0.852595 -0.056461  0.068703  0.269125 -0.520476  0.556008  0.267558
# 8   1.555951  1.677211  0.166017  0.065014  0.270944 -1.019210 -0.466233
# 9   1.631727 -0.056461  0.068703  0.434620  0.717576 -0.211199  0.824915
# 10  1.084297 -0.859086 -0.535590  2.109761  0.415731  1.409203  1.521413
# 11 -0.487692 -1.661712 -1.071323  0.564164 -0.540002 -1.000673 -1.535760
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['VIF values'] = [variance_inflation_factor(x.values,i) for i in range (len(x.columns))]
vif['Features']=x.columns

# %%
vif
# Out:
#     VIF values Features
# 0     4.267272        R
# 1     3.017872        H
# 2     2.707029       3B
# 3     6.119456       HR
# 4     3.183995       BB
# 5     2.866970       SO
# 6     1.964104       SB
# 7   177.894691       RA
# 8   169.716664       ER
# 9     1.879533       CG
# 10    3.025046      SHO
# 11    2.787792       SV
# 12    1.673825        E

# %%
x.drop('ER',axis=1,inplace=True)
vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['Features']=x.columns
vif
# Out:
#     VIF values Features
# 0     3.985045        R
# 1     2.811725        H
# 2     2.689230       3B
# 3     4.297306       HR
# 4     2.754099       BB
# 5     2.254441       SO
# 6     1.865983       SB
# 7     3.937108       RA
# 8     1.824069       CG
# 9     2.892955      SHO
# 10    2.375574       SV
# 11    1.393536        E

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score
from sklearn.ensemble import GradientBoostingRegressor

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=.30, random_state=i)
    GBR=GradientBoostingRegressor()
    GBR.fit(x_train,y_train)
    pred=GBR.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc > maxAccu:
        maxAccu=acc
        maxRS=i
print('Maximum r2 score is ',maxAccu ,'on Random_state ',maxRS)
# Out:
# Maximum r2 score is  0.774419632901339 on Random_state  102

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=.30, random_state=4)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge

# %%
LR= LinearRegression()
LR.fit(x_train,y_train)
pred=LR.predict(x_test)
print('R2_score:',r2_score(y_test,pred))
print('Mean absolute Error',mean_absolute_error(y_test,pred))
print('Mean squared Error',mean_squared_error(y_test,pred))
print('Root Mean absolute Error',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.7893937480762507
# Mean absolute Error 3.9153675369312597
# Mean squared Error 18.94416236440046
# Root Mean absolute Error 4.352489214736834

# %%
RFR= RandomForestRegressor()
RFR.fit(x_train,y_train)
pred=RFR.predict(x_test)
print('R2_score:',r2_score(y_test,pred))
print('Mean absolute Error',mean_absolute_error(y_test,pred))
print('Mean squared Error',mean_squared_error(y_test,pred))
print('Root Mean absolute Error',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.7552555860554488
# Mean absolute Error 3.7933333333333317
# Mean squared Error 22.014911111111115
# Root Mean absolute Error 4.692005020362949

# %%
knn=KNN()
knn.fit(x_train,y_train)
pred=knn.predict(x_test)
print('R2_score:',r2_score(y_test,pred))
print('Mean absolute Error',mean_absolute_error(y_test,pred))
print('Mean squared Error',mean_squared_error(y_test,pred))
print('Root Mean absolute Error',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.6081800713697503
# Mean absolute Error 4.933333333333333
# Mean squared Error 35.24444444444444
# Root Mean absolute Error 5.936703162904849

# %%
GRB= GradientBoostingRegressor()
GRB.fit(x_train,y_train)
pred=GRB.predict(x_test)
print('R2_score:',r2_score(y_test,pred))
print('Mean absolute Error',mean_absolute_error(y_test,pred))
print('Mean squared Error',mean_squared_error(y_test,pred))
print('Root Mean absolute Error',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.784519499045701
# Mean absolute Error 3.4765153795247365
# Mean squared Error 19.382604073494107
# Root Mean absolute Error 4.402567895387203

# %%
lasso= Lasso()
lasso.fit(x_train,y_train)
pred=lasso.predict(x_test)
print('R2_score:',r2_score(y_test,pred))
print('Mean absolute Error',mean_absolute_error(y_test,pred))
print('Mean squared Error',mean_squared_error(y_test,pred))
print('Root Mean absolute Error',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.855089732160133
# Mean absolute Error 3.0899226910924917
# Mean squared Error 13.034768042978655
# Root Mean absolute Error 3.610369516126937

# %%
rd= Ridge()
rd.fit(x_train,y_train)
pred=rd.predict(x_test)
print('R2_score:',r2_score(y_test,pred))
print('Mean absolute Error',mean_absolute_error(y_test,pred))
print('Mean squared Error',mean_squared_error(y_test,pred))
print('Root Mean absolute Error',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.8364924975330867
# Mean absolute Error 3.5613112267934053
# Mean squared Error 14.707600777455923
# Root Mean absolute Error 3.835048992836457

# %%
from sklearn.model_selection import cross_val_score

print(cross_val_score(LR,x,y,cv=5).mean())
print(cross_val_score(RFR,x,y,cv=5).mean())
print(cross_val_score(GBR,x,y,cv=5).mean())
print(cross_val_score(knn,x,y,cv=5).mean())
print(cross_val_score(rd,x,y,cv=5).mean())
print(cross_val_score(lasso,x,y,cv=5).mean())
# Out:
# 0.383563927919423
# -0.5982933221548796
# -1.6194090260308838
# -0.20180727622468578
# 0.42337438809908445
# 0.4796378166815035

# %%
model=Ridge(alpha=2, fit_intercept=True,positive=False,random_state=1,solver='auto')

# %%
model.fit(x_train,y_train)
pred=model.predict(x_test)
print('R2_score:',r2_score(y_test,pred))
print('Mean absolute Error',mean_absolute_error(y_test,pred))
print('Mean squared Error',mean_squared_error(y_test,pred))
print('Root Mean absolute Error',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.8456280223413832
# Mean absolute Error 3.392866926561393
# Mean squared Error 13.885854681736816
# Root Mean absolute Error 3.726372858657171

# %%
import joblib
joblib.dump(model,"Baseball")
# Out:
# ['Baseball']

# %%
loadmodel=joblib.load('Baseball')
a=np.array(y_test)
predicted=np.array(loadmodel.predict(x_test))
df_final=pd.DataFrame({"Original":a, "Predicted":predicted}, index=range(len(a)))
df_final
# Out:
#    Original  Predicted
# 0        85  80.337365
# 1        71  67.823883
# 2        74  72.680167
# 3        98  91.349603
# 4        83  85.976711
# 5        92  89.857103
# 6        68  72.134440
# 7        84  87.645517
# 8        90  88.172745

# %%
plt.figure(figsize=(8,8))
sns.regplot(x=y_test,y=predicted,data=None)
plt.xlabel('Actual Win')
plt.ylabel('Predicted Win')
plt.title('Ridge Regressor')
plt.show()

# %%
#Ridge model regressor has higher accuracy
